# %%
import pandas as pd
import eikon as ek
import warnings
import datetime

# %%
ek.set_app_key('4b3a2041ad65478b91d46404ba35a4f4d2413f6c')

sdate_for_year = "2024-05-01" #licence from UZH: 2017-01-01

df, e =ek.get_data(instruments = 'NESN.S',
                   fields = ["TR.FundInvestorType(TheInvestorType=404)", "TR.FundPortfolioName", 
                             "TR.FundTotalEquityAssets", "TR.FdAdjSharesHeldValue(SortOrder=Descending)", 
                             "TR.FundAddrCountry", "TR.FdAdjSharesHeldValue.date"],
                   parameters = {'EndNum':'100', "SDate": sdate_for_year, "Curn":"EUR", "Scale":6})

#, "TR.FundInvtOrientation(TheInvestorType=400)"
#df = df.sort_values("Fund Value Held (Adjusted)", ascending = False)
#df.columns = ["stock_RIC", "fund_type", "fund_name", "stock_value_held", "market_cap_fund", "country"]
display(df)
# Out:
# C:\Users\Shadow\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\eikon\data_grid.py:255: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors='ignore')
#    Instrument Fund Type Description  \
# 0      NESN.S  Exchange-Traded Fund
# 1      NESN.S  Exchange-Traded Fund
# 2      NESN.S  Exchange-Traded Fund
# 3      NESN.S  Exchange-Traded Fund
# 4      NESN.S  Exchange-Traded Fund
# ..        ...                   ...
# 95     NESN.S  Exchange-Traded Fund
# 96     NESN.S  Exchange-Traded Fund
# 97     NESN.S  Exchange-Traded Fund
# 98     NESN.S  Exchange-Traded Fund
# 99     NESN.S  Exchange-Traded Fund
#
#                                             Fund Name  \
# 0                         Statens Pensjonsfond Utland
# 1       Vanguard Total International Stock Index Fund
# 2               Vanguard Developed Markets Index Fund
# 3       CSIF (CH) Switzerland Total Market Index Blue
# 4                          iShares Core MSCI EAFE ETF
# ..                                                ...
# 95                      American Funds New World Fund
# 96              Vanguard Total World Stock Index Fund
# 97  Vanguard FTSE Developed Europe ex-UK Equity Index
# 98            Swisscanto (CH) Equity Fund Switzerland
# 99                    Schwab International Index Fund
#
#     Fund Portfolio Total Equity Assets  Fund Value Held (Adjusted)  \
# 0                        813309.472397                 8139.048646
# 1                        328328.454165                 3518.974049
# 2                        166398.386918                 2109.193732
# 3                           10053.1865                 1593.737344
# 4                        100000.286181                 1525.997899
# ..                                 ...                         ...
# 95                        46721.318584                  166.415267
# 96                        37670.341013                  149.291699
# 97                         4386.813065                  143.501812
# 98                          913.571245                  141.805903
# 99                         8518.564035                  141.168473
#
#    Fund Address Country                  Date
# 0                Norway  2023-12-31T00:00:00Z
# 1         United States  2024-02-29T00:00:00Z
# 2         United States  2024-02-29T00:00:00Z
# 3           Switzerland  2024-03-31T00:00:00Z
# 4         United States  2024-03-31T00:00:00Z
# ..                  ...                   ...
# 95        United States  2023-12-31T00:00:00Z
# 96        United States  2024-02-29T00:00:00Z
# 97        United States  2024-02-29T00:00:00Z
# 98          Switzerland  2024-02-29T00:00:00Z
# 99        United States  2024-02-29T00:00:00Z
#
# [100 rows x 7 columns]

# %%
import pandas as pd
import eikon as ek
import warnings
import datetime

# %%
ek.set_app_key('4b3a2041ad65478b91d46404ba35a4f4d2413f6c')

df = pd.DataFrame({
    'RIC': ['ASML.AS', 'NESN.S', 'SCMN.S', 'ASLO.PA'],
    'name': ["ASML HOLDING NV", "NESTLE SA", "SWISSCOM AG", "ALSOM SA"]
})


sdate_for_year = "2024-03-31" #licence from UZH: 2017-01-01


df, e =ek.get_data(instruments = 'NESN.S',
                   fields = ["TR.FundInvestorType(TheInvestorType=404)", "TR.FundPortfolioName", "TR.FundTotalEquityAssets", "TR.FdAdjSharesHeldValue(SortOrder=Descending)", "TR.FundAddrCountry"],
                   parameters = {'EndNum':'300', "SDate": sdate_for_year, "Curn":"EUR", "Scale":6})


df = df.sort_values("Fund Value Held (Adjusted)", ascending = False)
df.columns = ["stock_RIC", "fund_type", "fund_name", "stock_value_held", "market_cap_fund", "country"]
display(df)
# Out:
# C:\Users\Shadow\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\eikon\data_grid.py:255: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors='ignore')
#     stock_RIC             fund_type  \
# 0      NESN.S  Exchange-Traded Fund
# 1      NESN.S  Exchange-Traded Fund
# 2      NESN.S  Exchange-Traded Fund
# 3      NESN.S  Exchange-Traded Fund
# 4      NESN.S  Exchange-Traded Fund
# ..        ...                   ...
# 276    NESN.S  Exchange-Traded Fund
# 283    NESN.S  Exchange-Traded Fund
# 288    NESN.S  Exchange-Traded Fund
# 291    NESN.S  Exchange-Traded Fund
# 292    NESN.S  Exchange-Traded Fund
#
#                                             fund_name  stock_value_held  \
# 0                         Statens Pensjonsfond Utland     800046.316937
# 1       Vanguard Total International Stock Index Fund     322974.192992
# 2               Vanguard Developed Markets Index Fund     163684.822464
# 3       CSIF (CH) Switzerland Total Market Index Blue       9889.242786
# 4                          iShares Core MSCI EAFE ETF      98369.517837
# ..                                                ...               ...
# 276                  BNP Paribas Développement Humain       1627.346505
# 283             MFS Meridian Funds Global Equity Fund       2890.233617
# 288  NBI Int'l High Conviction Eqt Priv Portfolio Adv        878.977294
# 291                            KLP AksjeGlobal Indeks       9812.231647
# 292               iShares MSCI Europe ex-UK UCITS ETF       1467.974167
#
#      market_cap_fund         country
# 0        8139.048646          Norway
# 1        3518.974049   United States
# 2        2109.193732   United States
# 3        1554.936355     Switzerland
# 4        1462.173396   United States
# ..               ...             ...
# 276        51.621191          France
# 283        50.993557   United States
# 288        49.330783          Canada
# 291         48.80745          Norway
# 292        48.712753  United Kingdom
#
# [300 rows x 6 columns]

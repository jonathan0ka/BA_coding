# %% [markdown]
# # testing api requests

# %%
import pandas as pd
import eikon as ek
import warnings
import datetime
pd.set_option("display.max_rows", None)


hsg_24 = "825c77d2d6cb4b3ba41d25d4c0b87c46325cd98c"
ek.set_app_key(hsg_24)

# %%
cols1 = ['TR.ETPConstituentRIC',
       'TR.ETPConstituentName',
       'TR.ETPConstituentShares.date',
       'TR.ETPConstituentShares',
       'TR.ETPConstituentWeightPercent']
 
df1, e = ek.get_data('.STOXX',cols1, {'SDate':'2020-02-04'})
display(df1)

# %%
# df, e = ek.get_data('NESN.S',['TR.CategoryOwnershipPct','TR.InstrStatTypeValue'],
#             {'SDate':'20240101'})

df, e = ek.get_data(
          instruments = ['NESN.S'],
          fields = [          
               'TR.CatFundOwnershipPct',
               'TR.InstrFdStatCatShrsHld',
               'TR.InstrFdStatCatShHldVal',
               'TR.InstrFundStatType'
          ] 
)

display(df)
# Out:
# C:\Users\Shadow\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\eikon\data_grid.py:255: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors='ignore')
# C:\Users\Shadow\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\dtypes\cast.py:1057: RuntimeWarning: invalid value encountered in cast
#   if (arr.astype(int) == arr).all():
# C:\Users\Shadow\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\dtypes\cast.py:1081: RuntimeWarning: invalid value encountered in cast
#   if (arr.astype(int) == arr).all():
#     Instrument  Category Fund Percent Of Traded Shares  \
# ...

# %%
ek.set_app_key('80631b9534434526bb7b73ad26db914d4c2d9769')

sdate_for_year = "2024-02-01" #licence from UZH: 2017-01-01

df, e = ek.get_data(instruments = ["NESN.S", "ASML.AS"],
                    fields = ["TR.FundParentType",
                             "TR.FundInvestorType",
                             "TR.FundInvtStyleCode",
                             #############################################################
                             "TR.FundPortfolioName", 
                             "TR.FundTotalEquityAssets", 
                             "TR.FdAdjSharesHeldValue(SortOrder=Descending)",
                             #############################################################
                             "TR.FdAdjPctOfShrsOutHeld",
                             "TR.FundPctPortfolio",
                             "TR.FundAddrCountry",
                             "TR.FdAdjSharesHeldValue.date"],
                             parameters = {'EndNum':'100', "SDate": sdate_for_year, "Curn":"EUR", "Scale":6})

#, "TR.FundInvtOrientation(TheInvestorType=400)"
#df = df.sort_values("Fund Value Held (Adjusted)", ascending = False)
#df.columns = ["stock_RIC", "fund_type", "fund_name", "stock_value_held", "market_cap_fund", "country"]
display(df)
# Out:
# C:\Users\Shadow\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\eikon\data_grid.py:255: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors='ignore')
#     Instrument Fund Parent Type Description Fund Type Description  \
# 0       NESN.S                        Funds           Mutual Fund
# 1       NESN.S                        Funds           Mutual Fund
# 2       NESN.S                        Funds           Mutual Fund
# 3       NESN.S                        Funds           Mutual Fund
# 4       NESN.S                        Funds  Exchange-Traded Fund
# ..         ...                          ...                   ...
# 195    ASML.AS                        Funds  Exchange-Traded Fund
# 196    ASML.AS                        Funds           Mutual Fund
# ...

# %%
display(df)
# Out:
#    Instrument Fund Type Description  Fund Parent Type Description  Fund Name  \
# 0      NESN.S  Exchange-Traded Fund                          <NA>       <NA>
# 1      NESN.S  Exchange-Traded Fund                          <NA>       <NA>
# 2      NESN.S  Exchange-Traded Fund                          <NA>       <NA>
# 3      NESN.S  Exchange-Traded Fund                          <NA>       <NA>
# 4      NESN.S  Exchange-Traded Fund                          <NA>       <NA>
# ..        ...                   ...                           ...        ...
# 95     NESN.S  Exchange-Traded Fund                          <NA>       <NA>
# 96     NESN.S  Exchange-Traded Fund                          <NA>       <NA>
# 97     NESN.S  Exchange-Traded Fund                          <NA>       <NA>
# 98     NESN.S  Exchange-Traded Fund                          <NA>       <NA>
# 99     NESN.S  Exchange-Traded Fund                          <NA>       <NA>
#
# ...

# %% [markdown]
# etf data to get index membership

# %%
ek.set_app_key('4b3a2041ad65478b91d46404ba35a4f4d2413f6c')

sdate_for_year = "2024-02-01" #licence from UZH: 2017-01-01

df, e = ek.get_data(instruments = 'STOXXIEX.DE',
                   fields = 'TR.ETPConstituentRIC')
                  # parameters = {"SDate": sdate_for_year, "Curn":"EUR", "Scale":6})

#, "TR.FundInvtOrientation(TheInvestorType=400)"
#df = df.sort_values("Fund Value Held (Adjusted)", ascending = False)
#df.columns = ["stock_RIC", "fund_type", "fund_name", "stock_value_held", "market_cap_fund", "country"]
display(df)
# Out:
# C:\Users\Shadow\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\eikon\data_grid.py:255: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors='ignore')
#     Instrument  Constituent RIC
# 0  STOXXIEX.DE             <NA>

# %% [markdown]
# ## anomalies 2015-03-01 to 2015-11-01

# %%
import pandas as pd

df = pd.read_csv("/Users/jonathanzeh/Library/CloudStorage/OneDrive-Personal/BA_Thesis/BA_coding/datasets/eikon_data/fund_holdings_data/raw_data/etf_holdings_600_stocks_2014_01_2015_11.csv")

df_2 = pd.read_csv("/Users/jonathanzeh/Library/CloudStorage/OneDrive-Personal/BA_Thesis/BA_coding/datasets/eikon_data/fund_holdings_data/raw_data/etf_holdings_600_stocks_2014_07_2016_11.csv")
